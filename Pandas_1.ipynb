# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeep838116/Pandas/blob/main/Pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas is a newer package built on the top of NumPy, and provides an efficient implementation of a DataFrame. DataFrames are essentially multidimensional arrays with attached row and column labels, and often with heterogenous types and/or missing data. As well ass offering a convenient storage interface for labeled data.

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# # Introducing Pandas Objects
# - At the very basic level, Pandas objects can be thought of as enhanced versions of NumPy structured arrays in which the rows and columns are identified with labels rather than simple integers.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## The Pandas Series Object

# %%
# A Pandas series is one-dimensional array of indexed data.
data = pd.Series([0.25,0.5,0.75,1.0])
data
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64

# %%
# The Series wraps both a sequence of values and a sequence of indices, which we can access with the values and index attributes.
data.values
# Out:
# array([0.25, 0.5 , 0.75, 1.  ])

# %%
# The index is an array-like object of type pd.Index
data.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
#Like with a NumPy array, data can be accessed by the associated index via the fimiliar Python square-bracket notation:
data[1]
# Out:
# np.float64(0.5)

# %%
data[1:3]
# Out:
# 1    0.50
# 2    0.75
# dtype: float64

# %% [markdown]
# ### Series as generalized NumPy array
# - From what we have seen so far, it may look the Series object is basically interchangeable with one-dimensional NumPy array.
# - The essential difference is the presence of index: While the NumPy array has an implicitly defined integer index used to access the values, the Pandas Series has an explicitly defined index associated with the values.
# - This explicit index definition gives the Series object additional capablities.For example, the index need not be an integer, but can consist of values of any desired type.

# %%
data=pd.Series([0.25,0.2,0.75,1.0],index=['a','b','c','d'])
data
# Out:
# a    0.25
# b    0.20
# c    0.75
# d    1.00
# dtype: float64

# %%
data['b']
# Out:
# np.float64(0.2)

# %%
# We can even use noncontigous or nonsequential indices:
data=pd.Series([0.25,0.2,0.75,1.0],index=[2,5,3,7])
data
# Out:
# 2    0.25
# 5    0.20
# 3    0.75
# 7    1.00
# dtype: float64

# %%
data[5]
# Out:
# np.float64(0.2)

# %% [markdown]
# ### Series as specialized dictionary
# - A dictionary is a structure that maps types keys to a set of arbitary values, and a Series is structure that maps typed keys to a set of typed values.
# - This typing is important: just as the type-specific compiled code behind a NumPy array make it more efficient than a Python list for certain operations, the type information of a Pandas Series makes it more efficient than Python dictionaries for certain operations.

# %%
# We can make the Series-as-dictionary analogy even more clear by constructing a series object directly from a Python dictionary:
population_dict={'California':123456789,
                 'Sasaram':789456123,
                 'Delhi':741852963,
                 'Kolkata':963852741,
                 'Varanasi':159263487}
population = pd.Series(population_dict)
population
# Out:
# California    123456789
# Sasaram       789456123
# Delhi         741852963
# Kolkata       963852741
# Varanasi      159263487
# dtype: int64

# %%
population['Sasaram']
# Out:
# np.int64(789456123)

# %%
# Unlike a dictionary, though, the series also supports array-style operations such as slicing
population['California':'Kolkata']
# Out:
# California    123456789
# Sasaram       789456123
# Delhi         741852963
# Kolkata       963852741
# dtype: int64

# %% [markdown]
# ### Constructing series objects

# %%
pd.Series(data)
# Out:
# 2    0.25
# 5    0.20
# 3    0.75
# 7    1.00
# dtype: float64

# %%
pd.Series([2,4,6])
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64

# %%
# data can be scalar, which is represented to fill the specified index:
pd.Series(5,index=[1,2,3,4,5,6])
# Out:
# 1    5
# 2    5
# 3    5
# 4    5
# 5    5
# 6    5
# dtype: int64

# %%
#data can be a dictionary, in which index defaults to the sorted dictionary keys
pd.Series({2:'a',1:'b',3:'c'})
# Out:
# 2    a
# 1    b
# 3    c
# dtype: object

# %%
# In each case, index can be explicitly set if a different result is prefered
pd.Series({2:'a',1:'b',3:'c'},index=[3,2])
# Out:
# 3    c
# 2    a
# dtype: object

# %% [markdown]
# ## The Pandas DataFrame Object

# %% [markdown]
# ### DataFrame as a generalized NumPy array
# - If a series is an analog of a one-dimensional array with flexible indices, a DataFrame is an analog of a two-dimensional array with both flexible row indices and flexible column names.
# - Just as you might think of a two-dimensional array as an ordered sequence of aligned one-dimensional columns, you can think of a DataFrame as a sequence of aligned Series objects. Here, aligned means they share the same index.

# %%
area_dict={'California':123456,
                 'Sasaram':789456,
                 'Delhi':741852,
                 'Kolkata':963852,
                 'Varanasi':159263}
area = pd.Series(area_dict)
area
# Out:
# California    123456
# Sasaram       789456
# Delhi         741852
# Kolkata       963852
# Varanasi      159263
# dtype: int64

# %%
# Now that we have this along with the population Series from before, we can use a dictionary to construct a single two-dimensional object
states=pd.DataFrame({'population':population,
                     'area':area})
states
# Out:
#             population    area
# California   123456789  123456
# Sasaram      789456123  789456
# Delhi        741852963  741852
# Kolkata      963852741  963852
# Varanasi     159263487  159263

# %%
#Like series object, the DataFrame has an index attribute that gives access to the index labels:
states.index
# Out:
# Index(['California', 'Sasaram', 'Delhi', 'Kolkata', 'Varanasi'], dtype='object')

# %%
# Additionally, the DataFrame has a column attribute, which is an Index object holding the column labels:
states.columns
# Out:
# Index(['population', 'area'], dtype='object')

# %% [markdown]
# ### DataFrame as specialized dictionary
# - Similarly, we can think of a DataFrame as a specialization of a dictionary. Where a dictionary maps a keys to a value, a DataFrame maps a column name to a Series of column data.

# %%
states['area']
# Out:
# California    123456
# Sasaram       789456
# Delhi         741852
# Kolkata       963852
# Varanasi      159263
# Name: area, dtype: int64

# %% [markdown]
# Notice the potential point of confusion here: in a two-dimensional NumPy array, data[0] will return the first row. For a DataFrame, data['col0'] will return the first column. Because of this, it is probably better to think about Dataframes as generalized dictionaries rather than generalized arrays.

# %% [markdown]
# ### Constructing DataFrame objects

# %%
# From a single Series Object
# A DataFrame is a collection of Series objects, and a single-column DataFrame can be constructed from a single Series.
pd.DataFrame(population,columns=['population'])
# Out:
#             population
# California   123456789
# Sasaram      789456123
# Delhi        741852963
# Kolkata      963852741
# Varanasi     159263487

# %%
# From a list of dicts
# Any list of dictionaries can be made into a DataFrame.
data =[{'a':i,'b':2*i} for i in range(3)]
pd.DataFrame(data)
# Out:
#    a  b
# 0  0  0
# 1  1  2
# 2  2  4

# %%
# Even if some keys in the dictionary are missing, Pandas will fill them in with NaN(i.e.,"not a number") values
pd.DataFrame([{'a':1,'b':2},{'b':3,'c':4}])
# Out:
#      a  b    c
# 0  1.0  2  NaN
# 1  NaN  3  4.0

# %%
# From a dictionary of Series objects
pd.DataFrame({'population':population,'area':area})
# Out:
#             population    area
# California   123456789  123456
# Sasaram      789456123  789456
# Delhi        741852963  741852
# Kolkata      963852741  963852
# Varanasi     159263487  159263

# %%
# From a two-dimensional NumPy array
pd.DataFrame(np.random.rand(3,2),
             columns=['foo','bar'],
             index=['a','b','c'])
# Out:
#         foo       bar
# a  0.036298  0.719144
# b  0.997058  0.800736
# c  0.149808  0.071248

# %%
# From NumPy structured array
A = np.zeros(3,dtype=[("A",'i8'),('B','f8')])
pd.DataFrame(A)
# Out:
#    A    B
# 0  0  0.0
# 1  0  0.0
# 2  0  0.0

# %% [markdown]
# ## The Pandas Index Object
# - The Index object is an intresting structure in itself, and it can be thought of either as an immutable array or as an order set (technically a multiset, as Index objects may contain repeated values). Those views have some intresting consequences in the operations available on Index objects.

# %%
ind = pd.Index([2,3,4,5,7])
ind
# Out:
# Index([2, 3, 4, 5, 7], dtype='int64')

# %% [markdown]
# ### Index as immutable array

# %%
ind[1]
# Out:
# np.int64(3)

# %%
ind[::2]
# Out:
# Index([2, 4, 7], dtype='int64')

# %%
# One difference difference between Index objects and NumPy arrays is that indices are immutable-that is, they cannot be modified via the normal means.
ind[1]=0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1127/1090718869.py in <cell line: 0>()
#       1 # One difference difference between Index objects and NumPy arrays is that indices are immutable-that is, they cannot be modified via the normal means.
# ----> 2 ind[1]=0
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    5369     @final
#    5370     def __setitem__(self, key, value) -> None:
# -> 5371         raise TypeError("Index does not support mutable operations")
#    5372
#    5373     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %% [markdown]
# This immutability makes it safer to share indices between multiple DataFrames and arrays, without the potential for side effects from inadvertent index modifications.

# %% [markdown]
# ### Index as ordered set
# - Pandas objects are designed to facilitate operations such as join across datasets, which depend on many aspects of set arithemetic. The index object follows many of the conventions used by Python's built-in set data structure, so that unions, intersections, difference, and other combinations can be computed in a fimilar way.

# %%
indA=pd.Index([1,3,5,7,9])
indB=pd.Index([2,3,5,7,11])

# %%
indA&indB
# Out:
# Index([0, 3, 5, 7, 9], dtype='int64')

# %%
indA | indB
# Out:
# Index([3, 3, 5, 7, 11], dtype='int64')

# %%
indA ^ indB
# Out:
# Index([3, 0, 0, 0, 2], dtype='int64')
